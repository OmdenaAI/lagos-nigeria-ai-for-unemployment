# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("linkedin_jobs.csv")

# %%
dff = pd.read_csv('JOB SKILLS.csv')
dff.head(50)
# Out:
#                                                 Title  \
# 0                                  Front Desk Officer
# 1                     Customer Service Representative
# 2                                          Accountant
# 3                                           Assistant
# 4                                   HR Representative
# 5                                              Oracle
# 6                       Legal/Governance/HR Executive
# 7                          Human Resources Supervisor
# 8                            Customer Service Officer
# 9                                   Program Associate
# 10                                   Graduate Trainee
# 11                                      Store Officer
# 12                            Head Of Human Resources
# 13                                       Office Clerk
# 14                                 Accountant/Auditor
# 15                                         Remote Job
# 16                                Project Coordinator
# 17                                       Risk Advisor
# 18                                   Subject Teachers
# 19                                 Trainee Industrial
# 20                           OPERATIONS/ADMIN MANAGER
# 21                       Secretary/Personal Assistant
# 22                             Receptionist & Cashier
# 23                                    REVENUE MANAGER
# 24                               Nutrition Specialist
# 25  Public Health Administrative Management Assist...
# 26                      Software Testers/IT Help Desk
# 27                        DIGITAL MARKETING EXECUTIVE
# 28                                Executive Assistant
# 29                                         Admin Lead
# 30  Communications Officer (NOB), FT at the United...
# 31                     Procurement/Purchasing Officer
# 32                                            Cashier
# 33  Communication for Development Specialist � NER...
# 34                            Food & Beverage Manager
# 35  Medical Laboratory Scientist (Entry-level) at ...
# 36                        Agricultural Process Leader
# 37                                   Office Secretary
# 38  Human Resources Generalist at Scib Nigeria & C...
# 39                             Human Resources Intern
# 40                               Laboratory Personnel
# 41                 Graduate Energy Accounting Officer
# 42                                    Finance Manager
# 43                        Head Of Business Operations
# 44                          Waste Management Operator
# 45                     Water Treatment Plant Operator
# 46  Associate Product Marketing Manager, Platforms...
# 47                                    Account Manager
# 48                                  Software Engineer
# 49       Nigeria Administration & Procurement Manager
#
#                                                Skills
# 0   manning the switchboard, receiving, endorsing ...
# 1   General Managerial/Administration, CRM systems...
# 2   financial reporting principles, MS Office, ACA...
# 3   Outlook, Excel, Word, PowerPoint, Google Sprea...
# 4   Human Resources or related discipline, Labour ...
# 5   Cloud Service experience, selling technology-r...
# 6   Telecom Technologies, Internet of Things, Smar...
# 7   CHR, SHRM, CIPD, Microsoft Office applications...
# 8   Computer literacy, sales experience, customer ...
# 9   administrative work, accounting/finance, econo...
# 10  leadership, self-motivated, management skills,...
# 11  Purchasing software, Negotiation Skills, Micro...
# 12  employment-related laws, regulations, Microsof...
# 13  Computer skills, Microsoft Word, Excel, Powerp...
# 14  ICAN, ANAN ACCA, CIA, MS Office, ERP , CISA, C...
# 15  Web development using PHP, Python, Ruby or Go,...
# 16  PMP / PRINCE2, Microsoft Project , Microsoft P...
# 17  Governance and Accountability, ICAN, ACCA,CIA ...
# 18  Nigerian and British curriculum, Microsoft Wor...
# 19  MS word, Powerpoint, Excel, Wordpress, use bas...
# 20  project management, delegation, flexibility, r...
# 21  Microsoft office applications, communication s...
# 22  Basic Maths skills, Product knowledge, Loss Pr...
# 23   Microsoft Excel, Powerpoint, Sales report, Ce...
# 24  Research translation, Tech savvy, Organisation...
# 25  Electronic record systems, use of advanced med...
# 26  DevOps and Agile methodology, Rational analysi...
# 27  Wordpress, Google Ads, SEO Blogging, Keyword r...
# 28  Email management, Collaboration tools(Slack, G...
# 29  Microsoft office tools, Quickbooks and Xero, E...
# 30  Computer Aid Dispatch (CAD), Dispatch systems,...
# 31   Risk management software, Report generators, ...
# 32  Point Of Sale(POS) Systems, Multitasking, Basi...
# 33   Computer Aid Dispatch (CAD), Dispatch systems...
# 34  Culinary arts, Chef skills, Leadership skills,...
# 35  Diagnostic tests, Effective use of lab equipme...
# 36  Mechanical and repairing, Problem solving, Tec...
# 37  Microsoft Word, Excel, Outlook, Powerpoint, Sh...
# 38  HR Information Software, Performance managemen...
# 39  Business management, Finance, Legal knowledge,...
# 40  Pipetting, Sterilisation, Time management, Dat...
# 41  Analytical Skill, Health and Safety skills, Bu...
# 42  forecasting, Strategic planning, Business deve...
# 43  Interpersonal skills, risk assessment and anal...
# 44  Attention to details, team work, waste managem...
# 45  risk assessment, mechanical skills, instrument...
# 46  Marketing skills, UX design, brand management,...
# 47  general ledger, account management, strategic ...
# 48  object oriented programming, strategic plannin...
# 49  Negotiation skills, project management skills,...

# %%
df.sample(20)
# Out:
#                                                  Title  \
# 528                                   Graduate Trainee
# 376                      Legal/Governance/HR Executive
# 318                    Customer Service Representative
# 162    Account Manager at Fadac Resources and Services
# 97                                  Front Desk Officer
# 63   Submit CVs – New Recruitment at Oracle Nigeria...
# 65   Customer Service Officer at Pruvia Integrated ...
# 17                                  Accountant Auditor
# 166                                  Junior Accountant
# 636  Submit CVs – New Recruitment at Oracle Nigeria...
# 199               Project Coordinator at Oxfam Nigeria
# 556      Work from Home Opportunities | Flexible Hours
# 597                                   Graduate trainee
# 158  Human Resources Generalist at Scib Nigeria & C...
# 327                                   Graduate Trainee
# 111                                    Finance Manager
# 502               Software Engineer (Graduate Trainee)
# 96                          Líder De Processo Agrícola
# 413                           Customer Service Manager
# 568                                   Graduate Trainee
#
#                                        Job Description  \
# 528  Be open to learn new things and enjoy the lear...
# 376  JOB BRIEFWe are a corporate services firm that...
# 318  SummaryOur client, (a reputable retail gas sto...
# 162  Never Miss a Job Update Again. Company: Locati...
# 97   * Oversee all secretarial duties at entrance d...
# 63   Never Miss a Job Update Again. Company: Locati...
# 65   Never Miss a Job Update Again. Company: Locati...
# 17   Duties/Responsibilities:* Examines assigned fi...
# 166  The Junior account responsibilities include bu...
# 636  Never Miss a Job Update Again. Company: Locati...
# 199  Never Miss a Job Update Again. Company: Locati...
# 556  Appen is a global leader in speech and search ...
# 597  Ensure high levels of customer satisfaction th...
# 158  Never Miss a Job Update Again. Company: Locati...
# 327  Candidate must be domiciled in/around Lagos.Ca...
# 111  Reporting to the CFO, the Finance Manager role...
# 502  We are looking to hire an entry level Software...
# 96   Área De AtuaçãoDiversosLocalizaçãoDelta-MGAtri...
# 413  HENKEL IS FOR THOSE WHO STEP UP. DO YOU?At Hen...
# 568  The Robotics Centre,an Artificial Intelligence...
#
#                      Compnay Name                         Location  \
# 528    Sapphire Health Management                 Bayelsa, Nigeria
# 376    KNN Corporate Services Ltd            Lagos, Lagos, Nigeria
# 318                    WorQulture                   Lagos, Nigeria
# 162  Fadac Resources and Services            Lagos, Lagos, Nigeria
# 97             TD Global Resource                   Lagos, Nigeria
# 63                 Oracle Limited            Lagos, Lagos, Nigeria
# 65      Pruvia Integrated Limited            Lagos, Lagos, Nigeria
# 17                 Chiji14xchange            Lagos, Lagos, Nigeria
# 166                Advans Nigeria             Ibadan, Oyo, Nigeria
# 636                Oracle Limited            Lagos, Lagos, Nigeria
# 199                         Oxfam          Bauchi, Bauchi, Nigeria
# 556                         Appen                   Lagos, Nigeria
# 597                           LDG            Ojota, Lagos, Nigeria
# 158    Scib Nigeria & Co. Limited            Lagos, Lagos, Nigeria
# 327      EK Resources Nigeria Ltd                   Lagos, Nigeria
# 111         Africa Prudential Plc                   Lagos, Nigeria
# 502                   SFS Capital                   Lagos, Nigeria
# 96                 Expresso Vagas                   Delta, Nigeria
# 413                        Henkel             Ibadan, Oyo, Nigeria
# 568       Robotics Centre limited  Lekki Peninsula, Lagos, Nigeria
#
#     Date Posted                                      LinkedIn Link
# 528  2021-11-03  https://ng.linkedin.com/jobs/view/graduate-tra...
# 376  2021-11-06  https://ng.linkedin.com/jobs/view/legal-govern...
# 318  2021-11-06  https://ng.linkedin.com/jobs/view/customer-ser...
# 162  2021-11-03  https://ng.linkedin.com/jobs/view/account-mana...
# 97   2021-11-06  https://ng.linkedin.com/jobs/view/front-desk-o...
# 63   2021-11-02  https://ng.linkedin.com/jobs/view/submit-cvs-%...
# 65   2021-11-02  https://ng.linkedin.com/jobs/view/customer-ser...
# 17   2021-11-06  https://ng.linkedin.com/jobs/view/accountant-a...
# 166  2021-11-03  https://ng.linkedin.com/jobs/view/junior-accou...
# 636  2021-11-02  https://ng.linkedin.com/jobs/view/submit-cvs-%...
# 199  2021-11-02  https://ng.linkedin.com/jobs/view/project-coor...
# 556  2021-11-02  https://ng.linkedin.com/jobs/view/work-from-ho...
# 597  2021-11-04  https://ng.linkedin.com/jobs/view/graduate-tra...
# 158  2021-11-02  https://ng.linkedin.com/jobs/view/human-resour...
# 327  2021-11-02  https://ng.linkedin.com/jobs/view/graduate-tra...
# 111  2021-11-04  https://ng.linkedin.com/jobs/view/finance-mana...
# 502  2021-11-06  https://ng.linkedin.com/jobs/view/software-eng...
# 96   2021-11-05  https://ng.linkedin.com/jobs/view/l%C3%ADder-d...
# 413  2021-11-02  https://ng.linkedin.com/jobs/view/customer-ser...
# 568  2021-10-30  https://ng.linkedin.com/jobs/view/graduate-tra...

# %%
df.rename(columns={'Compnay Name': 'Company Name'}, inplace=True)

# %%
df.replace({'Title':{'Work from Home Opportunities | Flexible Hours':'Remote Job',
                     'Submit CVs – New Recruitment at Oracle Nigeria (8 Positions)':'Oracle',
                    'Project Coordinator at Oxfam Nigeria': 'Project Coordinator',
                    'HR Representative at Dangote Group (2 Openings)': 'HR Representative',
                     'Office Clerk at Pruvia Integrated Limited': 'Office Clerk',
                     'Líder De Processo Agrícola': 'Agricultural Process Leader',
                     'Secretary / Personal Assistant at Fadac Resources and Services': 'Secretary/Personal Assistant',
                     'Submit CVs – New Recruitment at Deloitte Nigeria (9 Positions)': 'Risk Advisor'
                     
                     }}, inplace=True)

# %%
df.replace({'Title':{'Executive Assistant at Fadac Resources and Services':'Executive Assistant',
                     'Procurement/ Purchasing Officer':'Procurement/Purchasing Officer',
                     'Cashier at Fadac Resources and Services':'Cashier'
                     
                    }}, inplace=True)

# %%
df.replace({'Title':{'Laboratory Personnel at the Dangote Petroleum Refinery':'Laboratory Personnel',
                     'Work from Home Opportunities (Part-time)':'Remote Job',
                     'Submit CVs – Latest Recruitment at Ikeja Electricity Distribution Company (IKEDC)':'Graduate Energy Accounting Officer',
                     'Waste Management Operator at Padua Petroleum Nigeria Limited (PPNL)':'Waste Management Operator',
                     'Water Treatment Plant Operator at Padua Petroleum Nigeria Limited (PPNL)':'Water Treatment Plant Operator',
                     'Account Manager at Fadac Resources and Services':'Account Manager',
                     'Software Engineer (Graduate Trainee)':'Software Engineer',
                     'Inspection Personnel at the Dangote Petroleum Refinery':'Inspection Personnel',
                     'Submit CVs – New Recruitment at Royal Hospital':'Accounting Officer Location',
                     'Submit CVs – Latest Recruitment at Medecins du Monde (MdM)':'External Facilitator',
                     'Receptionist at Zenith Carex International Limited':'Receptionist',
                     'Cashier at Eye Foundation Hospital':'Cashier',
                     'Executive Assistant to the Country Director at Oxfam Nigeria':'Executive Assistant',
                     'Submit your CV to TTC Mobile Limited (4 Positions)':'Field Support Technician',
                     'Office Secretary at Inspire Polytechnic':'Office Secretary',
                     'HR Officer at STRUGZ Nigeria':'HR Officer',
                     'Security Investigator at the U.S. Embassy':'Security Investigator',
                     'Submit CVs – New Recruitment at Oxfam Nigeria':'Head of Programmes and Influencing',
                     'Customer Service Executive at Pruvia Integrated Limited – Ikeja & Akowonjo':'Customer Service Executive',
                     'Travel Coordinator at the U.S. Embassy':'Travel Coordinator',
                     'Station Manager at United Nigeria Airlines':'Station Manager',
                     'Submit CVs – New Recruitment at Fadac Resources and Services':'Marketing Manager',
                     'Front Desk Officer at George Houston Resources Limited':'Front Desk Officer',
                     'Submit CVs – New Recruitment at Blume Nigeria Limited':'Territory Sales Manager',
                     'Submit CVs – New Recruitment at Prowedge Limited (11 Positions)':'Investor Relation Manager',
                     'Cashier at NENnetworks':'Cashier',
                     'Submit CVs – New Recruitment at Alert Microfinance bank':'Digital Transformation Manager',
                     'Customer Support Officer at Padua Petroleum Nigeria Limited (PPNL)':'Customer Support Officer',
                     'General Manager at KPMG Nigeria':'General Manager',
                     'Graduate HR Intern at Food Concepts Plc':'Graduate HR Intern',
                     'English and Math Instructors at HR Leverage Africa – 2 Openings':'English and Math Instructor',
                     'Administration Manager at Catilas Resources Limited':'Administration Manager',
                     'HR Officer at Hartleys Supermarket & Stores':'HR Officer',
                     'Assistant Accountant at Padua Petroleum Nigeria Limited':'Assistant Accountant',
                     'Junior Process Engineer – Flour Milling at Buhler Nigeria':'Junior Process Engineer',
                     'Graduate Management Trainee (Lagos) at Food Concepts Plc – 10 Openings':'Graduate Management Trainee',
                     'Medical Science Liaison Officer at 54Gene Nigeria':'Medical Science Liaison Officer',
                     'Fixed Line ':'Sales Officer'
                    }}, inplace=True)

# %%
df.replace({'Title':{ 'Submit CVs – New Recruitment at De Santiago Milan Hotel and Suites': 'Receptionist & Cashier'}}, inplace=True)

# %%
df.replace({'Title':{ 'Submit CVs – Latest Recruitment at United Nations International Children’s Emergency Fund (UNICEF)': 'Nutrition Specialist'}}, inplace=True)

# %%
df.drop(columns=['Date Posted','LinkedIn Link'], inplace=True)

# %%
df.head()
# Out:
#                              Title  \
# 0               Front Desk Officer
# 1  Customer Service Representative
# 2                       Accountant
# 3  Customer Service Representative
# 4                        Assistant
#
#                                      Job Description  \
# 0  * Oversee all secretarial duties at entrance d...
# 1  The ideal candidate loves talking to people an...
# 2  •Preparation of petty cash.• Posting of petty ...
# 3  SummaryOur client, (a reputable retail gas sto...
# 4  I need an assistant who is very proficient in ...
#
#                    Company Name               Location
# 0            TD Global Resource         Lagos, Nigeria
# 1  IQ SYSTEMS SOLUTIONS LIMITED         Lagos, Nigeria
# 2      Health insurance company  Lagos, Lagos, Nigeria
# 3                    WorQulture         Lagos, Nigeria
# 4      The Image Makers Company         Lagos, Nigeria

# %%
df.Title.unique()
# Out:
# array(['Front Desk Officer', 'Customer Service Representative',
#        'Accountant', 'Assistant', 'HR Representative', 'Oracle',
#        'Legal/Governance/HR Executive', 'Human Resources Supervisor',
#        'Customer Service Officer at Pruvia Integrated Limited',
#        'Program Associate', 'Graduate Trainee', 'Store Officer',
#        'Head Of Human Resources', 'Office Clerk', 'Accountant Auditor',
#        'Remote Job', 'Project Coordinator', 'Graduate trainee',
#        'Risk Advisor', 'Subject Teachers ', 'Trainee Industrial',
#        'OPERATIONS/ADMIN MANAGER', 'Secretary/Personal Assistant',
#        'Receptionist & Cashier', 'REVENUE MANAGER',
#        'Nutrition Specialist',
#        'Public Health Administrative Management Assistant at the U.S. Embassy',
#        'Software Testers/IT Help Desk', 'DIGITAL MARKETING EXECUTIVE',
#        'Executive Assistant', 'Admin Lead',
#        'Communications Officer (NOB), FT at the United Nations International Children’s Emergency Fund (UNICEF)',
#        'Procurement/Purchasing Officer', 'Cashier',
#        'Communication for Development Specialist – NERICC at the United Nations International Children’s Emergency Fund (UNICEF)',
#        'Food & Beverage Manager',
#        'Medical Laboratory Scientist (Entry-level) at Arkounting Business Concepts Limited',
#        'Agricultural Process Leader', 'Office Secretary',
#        'Human Resources Generalist at Scib Nigeria & Co. Limited',
#        'Human Resources Intern', 'Laboratory Personnel',
#        'Graduate Energy Accounting Officer', 'Finance Manager',
#        'Head Of Business Operations', 'Waste Management Operator',
#        'Water Treatment Plant Operator',
#        'Associate Product Marketing Manager, Platforms and Ecosystems',
#        'Account Manager', 'Software Engineer',
#        'Nigeria Administration & Procurement Manager',
#        'Customer Care Officer', 'Junior Accountant',
#        'Inspection Personnel', 'Partnerships & Sustainability Associate',
#        'Teaching Staff', 'Inventory Officer',
#        'Quality Assurance Analyst - Call Centre ', 'Inventory Accountant',
#        'Accounting Officer Location', 'Chief Operating Officer',
#        'External Facilitator', 'Procurement Officer', 'Receptionist',
#        'Customer Service Lead & Marketing  Rep', 'Marketing Coordinator',
#        'VISA OFFICER', 'Field Support Technician', 'HR Officer',
#        'Security Investigator', 'Head of Programmes and Influencing',
#        'Customer Service Executive', 'Travel Coordinator',
#        'School Human Resources Administrator', 'Hotel Manager',
#        'Station Manager', "'Administrative Logistics officer",
#        'Marketing Manager', 'Head Of Business',
#        'Partner Operations Intern', 'Territory Sales Manager',
#        'Sales Officer', 'Investor Relation Manager',
#        'Administrative assistant', 'Social Media Coordinator',
#        'Digital Transformation Manager', 'Customer Support Officer',
#        'Customer Service Manager', 'Office clerk', 'General Manager',
#        'Shipping and clearing Officer', 'Administrative Assistant',
#        'Graduate HR Intern', 'Senior Lead- Human Resources',
#        'English and Math Instructor', 'Administration Manager',
#        'Assistant Accountant', 'Junior Process Engineer',
#        'Junior Audit Officer', 'Administrative Officer',
#        'Graduate Management Trainee', 'Nutritionist',
#        'Head Treasury Marketing', 'Utilities Maintenance Controller',
#        'Medical Science Liaison Officer'], dtype=object)

# %%
df[['State', 'City', 'Street']] = df['Location'].str.split(',', expand=True)

# %%
df.head()
# Out:
#                              Title  \
# 0               Front Desk Officer
# 1  Customer Service Representative
# 2                       Accountant
# 3  Customer Service Representative
# 4                        Assistant
#
#                                      Job Description  \
# 0  * Oversee all secretarial duties at entrance d...
# 1  The ideal candidate loves talking to people an...
# 2  •Preparation of petty cash.• Posting of petty ...
# 3  SummaryOur client, (a reputable retail gas sto...
# 4  I need an assistant who is very proficient in ...
#
#                    Company Name               Location  State      City  \
# 0            TD Global Resource         Lagos, Nigeria  Lagos   Nigeria
# 1  IQ SYSTEMS SOLUTIONS LIMITED         Lagos, Nigeria  Lagos   Nigeria
# 2      Health insurance company  Lagos, Lagos, Nigeria  Lagos     Lagos
# 3                    WorQulture         Lagos, Nigeria  Lagos   Nigeria
# 4      The Image Makers Company         Lagos, Nigeria  Lagos   Nigeria
#
#      Street
# 0      None
# 1      None
# 2   Nigeria
# 3      None
# 4      None

# %%
df.drop(columns=['Location','City', 'Street'], inplace=True)

# %%
df
# Out:
#                                                  Title  \
# 0                                   Front Desk Officer
# 1                      Customer Service Representative
# 2                                           Accountant
# 3                      Customer Service Representative
# 4                                            Assistant
# ..                                                 ...
# 699                                         Admin Lead
# 700  Associate Product Marketing Manager, Platforms...
# 701                                    Account Manager
# 702                                         Remote Job
# 703                 Graduate Energy Accounting Officer
#
#                                        Job Description  \
# 0    * Oversee all secretarial duties at entrance d...
# 1    The ideal candidate loves talking to people an...
# 2    •Preparation of petty cash.• Posting of petty ...
# 3    SummaryOur client, (a reputable retail gas sto...
# 4    I need an assistant who is very proficient in ...
# ..                                                 ...
# 699  Job PurposeTo oversee and support all administ...
# 700  Minimum qualifications:Bachelor's degree or eq...
# 701  Never Miss a Job Update Again. Company: Locati...
# 702  We are looking for individuals for an exciting...
# 703  Never Miss a Job Update Again. Company: Locati...
#
#                      Company Name  State
# 0              TD Global Resource  Lagos
# 1    IQ SYSTEMS SOLUTIONS LIMITED  Lagos
# 2        Health insurance company  Lagos
# 3                      WorQulture  Lagos
# 4        The Image Makers Company  Lagos
# ..                            ...    ...
# 699                        M-KOPA  Lagos
# 700                        Google  Lagos
# 701  Fadac Resources and Services  Lagos
# 702                         Appen  Niger
# 703                Ikeja Electric  Lagos
#
# [704 rows x 4 columns]

# %%
df.rename(columns={'State': 'Location'}, inplace=True)

# %%
df
# Out:
#                                                  Title  \
# 0                                   Front Desk Officer
# 1                      Customer Service Representative
# 2                                           Accountant
# 3                      Customer Service Representative
# 4                                            Assistant
# ..                                                 ...
# 699                                         Admin Lead
# 700  Associate Product Marketing Manager, Platforms...
# 701                                    Account Manager
# 702                                         Remote Job
# 703                 Graduate Energy Accounting Officer
#
#                                        Job Description  \
# 0    * Oversee all secretarial duties at entrance d...
# 1    The ideal candidate loves talking to people an...
# 2    •Preparation of petty cash.• Posting of petty ...
# 3    SummaryOur client, (a reputable retail gas sto...
# 4    I need an assistant who is very proficient in ...
# ..                                                 ...
# 699  Job PurposeTo oversee and support all administ...
# 700  Minimum qualifications:Bachelor's degree or eq...
# 701  Never Miss a Job Update Again. Company: Locati...
# 702  We are looking for individuals for an exciting...
# 703  Never Miss a Job Update Again. Company: Locati...
#
#                      Company Name Location
# 0              TD Global Resource    Lagos
# 1    IQ SYSTEMS SOLUTIONS LIMITED    Lagos
# 2        Health insurance company    Lagos
# 3                      WorQulture    Lagos
# 4        The Image Makers Company    Lagos
# ..                            ...      ...
# 699                        M-KOPA    Lagos
# 700                        Google    Lagos
# 701  Fadac Resources and Services    Lagos
# 702                         Appen    Niger
# 703                Ikeja Electric    Lagos
#
# [704 rows x 4 columns]

# %%
df.Location.replace('Lekki Peninsula', 'Lagos', inplace=True)
df.Location.replace('Ojota', 'Lagos', inplace=True)
df.Location.replace('Lagos Mainland', 'Lagos', inplace=True)
df.Location.replace('Ajao Estate', 'Lagos', inplace=True)

# %%
df.Location.replace('Ikeja', 'Lagos', inplace=True)
df.Location.replace('Suru Lere', 'Lagos', inplace=True)
df.Location.replace('Obajana', 'Kogi', inplace=True)
df.Location.replace('Bayara', 'Bauchi', inplace=True)

# %%
df
# Out:
#                                                  Title  \
# 0                                   Front Desk Officer
# 1                      Customer Service Representative
# 2                                           Accountant
# 3                      Customer Service Representative
# 4                                            Assistant
# ..                                                 ...
# 699                                         Admin Lead
# 700  Associate Product Marketing Manager, Platforms...
# 701                                    Account Manager
# 702                                         Remote Job
# 703                 Graduate Energy Accounting Officer
#
#                                        Job Description  \
# 0    * Oversee all secretarial duties at entrance d...
# 1    The ideal candidate loves talking to people an...
# 2    •Preparation of petty cash.• Posting of petty ...
# 3    SummaryOur client, (a reputable retail gas sto...
# 4    I need an assistant who is very proficient in ...
# ..                                                 ...
# 699  Job PurposeTo oversee and support all administ...
# 700  Minimum qualifications:Bachelor's degree or eq...
# 701  Never Miss a Job Update Again. Company: Locati...
# 702  We are looking for individuals for an exciting...
# 703  Never Miss a Job Update Again. Company: Locati...
#
#                      Company Name Location
# 0              TD Global Resource    Lagos
# 1    IQ SYSTEMS SOLUTIONS LIMITED    Lagos
# 2        Health insurance company    Lagos
# 3                      WorQulture    Lagos
# 4        The Image Makers Company    Lagos
# ..                            ...      ...
# 699                        M-KOPA    Lagos
# 700                        Google    Lagos
# 701  Fadac Resources and Services    Lagos
# 702                         Appen    Niger
# 703                Ikeja Electric    Lagos
#
# [704 rows x 4 columns]

# %%
df['Job Description'] = df['Job Description'].str.lower()

# %%
Qual = ['b.ed', 'b.sc', 'b.tech', 'hnd', 'm.ed', 'm.sc', 'm.a', 'n.c.e', 'bsc', 'ond', 'msc', 'mba', 'mga', 'mma', 'nce', 'ma', 'h n d', 'o n d',
        'b tech', 'bachelors', 'bachelor','masters', 'master', 'p.h.d', 'phd',
        'p h d', 'pgd', 'p g d', 'p.g.d', 'ssce', 's s c e', 's.s.c.e', 'waec', 'w a e c', 'w.a.e.c']

df['Degree Type'] = df['Job Description'].str.findall('|'.join(Qual)).apply(set).str.join(', ')

# %%
df.sample(30)
# Out:
#                                                  Title  \
# 551                                      Store Officer
# 444                    Customer Service Representative
# 266                     Water Treatment Plant Operator
# 619                                   Office Secretary
# 593                                 Front Desk Officer
# 119                                   Office Secretary
# 122                                    REVENUE MANAGER
# 152                                         Remote Job
# 190  Customer Service Officer at Pruvia Integrated ...
# 509                               Junior Audit Officer
# 325                                  Program Associate
# 291                             Human Resources Intern
# 125                                         Admin Lead
# 487                      Legal/Governance/HR Executive
# 371                                         Accountant
# 622  Human Resources Generalist at Scib Nigeria & C...
# 673                                         Remote Job
# 639                                   Graduate Trainee
# 42                                  Trainee Industrial
# 240                    Customer Service Representative
# 645                                  Subject Teachers
# 506                                         HR Officer
# 31                                   Program Associate
# 667  Medical Laboratory Scientist (Entry-level) at ...
# 547  Customer Service Officer at Pruvia Integrated ...
# 414                               Laboratory Personnel
# 71                                   Subject Teachers
# 223                                       VISA OFFICER
# 373                                          Assistant
# 565                                  Software Engineer
#
#                                        Job Description  \
# 551  job summary:\tto manage the company’s store a...
# 444  summaryour client, (a reputable retail gas sto...
# 266  never miss a job update again. company: locati...
# 619  never miss a job update again. company: locati...
# 593  * oversee all secretarial duties at entrance d...
# 119  never miss a job update again. company: locati...
# 122  ibis hotel"some say you can't put a price on c...
# 152  appen is a global leader in speech and search ...
# 190  never miss a job update again. company: locati...
# 509  main responsibilities(1) planning activities :...
# 325  the organizationcentre for health ethics law a...
# 291  we are recruiting to fill the position belowjo...
# 125  job purposeto oversee and support all administ...
# 487  job briefwe are a corporate services firm that...
# 371  •preparation of petty cash.• posting of petty ...
# 622  never miss a job update again. company: locati...
# 673  appen is a global leader in speech and search ...
# 639  be open to learn new things and enjoy the lear...
# 42   área de atuaçãoindustriallocalizaçãodelta-mgat...
# 240  summaryour client, (a reputable retail gas sto...
# 645  a prestigious international schools group in i...
# 506  never miss a job update again. company: locati...
# 31   the organizationcentre for health ethics law a...
# 667  never miss a job update again. company: locati...
# 547  never miss a job update again. company: locati...
# 414  never miss a job update again. company: locati...
# 71   a prestigious international schools group in i...
# 223  *skills* : good communication and analytical s...
# 373  i need an assistant who is very proficient in ...
# 565  we are looking to hire an entry level software...
#
#                                           Company Name Location  \
# 551                             Ginos Ventures Limited    Abuja
# 444                                         WorQulture    Lagos
# 266                    Padua Petroleum Nigeria Limited    Lagos
# 619                                Inspire Polytechnic    Lagos
# 593                                 TD Global Resource    Lagos
# 119                                Inspire Polytechnic    Lagos
# 122                                               IBIS    Lagos
# 152                                              Appen    Lagos
# 190                          Pruvia Integrated Limited    Lagos
# 509                                     Advans Nigeria    Lagos
# 325       Centre For Health Ethics Law and Development    Lagos
# 291                           Precise Lighting Limited    Lagos
# 125                                             M-KOPA    Lagos
# 487                         KNN Corporate Services Ltd    Lagos
# 371                           Health insurance company    Lagos
# 622                         Scib Nigeria & Co. Limited    Lagos
# 673                                              Appen    Lagos
# 639                         Sapphire Health Management  Bayelsa
# 42                                      Expresso Vagas    Delta
# 240                                         WorQulture    Lagos
# 645  A prestigeous group of Schools in Lagos and En...    Lagos
# 506                      Hartleys Supermarket & Stores    Lagos
# 31        Centre For Health Ethics Law and Development    Lagos
# 667               Arkounting Business Concepts Limited    Lagos
# 547                          Pruvia Integrated Limited    Lagos
# 414                         Dangote Petroleum Refinery    Lagos
# 71   A prestigeous group of Schools in Lagos and En...    Lagos
# 223                                        TATAgencyNG    Lagos
# 373                           The Image Makers Company    Lagos
# 565                                        SFS Capital    Lagos
#
#                                       Degree Type
# 551         bsc, ma, ond, nce, mpa, mma, m a, hnd
# 444  ma, ond, bachelor, n cre, mpa, mma, nce, mea
# 266                   ma, bachelor, mpa, msc, nce
# 619                 b.sc, pgd, ond, mpa, nce, hnd
# 593                        bsc, ma, nce, m a, hnd
# 119                 b.sc, pgd, ond, mpa, nce, hnd
# 122                                  m a, ma, nce
# 152                             mpa, m!a, ma, nce
# 190                       ssce, ma, ond, mpa, nce
# 509                       b.sc, ma, ond, nce, hnd
# 325                            b.sc, m a, ma, nce
# 291                                            ma
# 125                  b.sc, m a, ma, ond, nce, hnd
# 487                        ma, ond, nce, mpa, m a
# 371
# 622                            mpa, b.sc, ma, nce
# 673                             mpa, m!a, ma, nce
# 639                            ssce, bsc, hnd, ma
# 42                              mpa, mga, ma, nce
# 240  ma, ond, bachelor, n cre, mpa, mma, nce, mea
# 645                                  m a, ma, nce
# 506        b.sc, m a, ma, ond, mpa, nce, mea, hnd
# 31                             b.sc, m a, ma, nce
# 667         m a, ma, ond, bachelor, mpa, nce, mea
# 547                       ssce, ma, ond, mpa, nce
# 414                        mpa, nce, ma, bachelor
# 71                                   m a, ma, nce
# 223                             ond, mba, ma, nce
# 373
# 565                             nce, ma, bachelor

# %%
df.Location.unique()
# Out:
# array(['Lagos', 'Kogi', 'Onitsha', 'Abuja', 'Bauchi', 'Bayelsa',
#        'Port Harcourt', 'Delta', 'Niger', 'Ibadan', 'Enugu', 'Borno',
#        'Anambra'], dtype=object)

# %%
len(df.Location.unique())
# Out:
# 13

# %%
df['Degree Type'].unique()
# Out:
# array(['bsc, ma, nce, m a, hnd', 'nce, msa, ma, ond', '',
#        'ma, ond, bachelor, n cre, mpa, mma, nce, mea',
#        'mpa, nce, ma, ond', 'mpa, mea, ma, nce', 'ma, ond, nce, mpa, m a',
#        'bachelors, mpa, ma, nce', 'ssce, ma, ond, mpa, nce',
#        'b.sc, m a, ma, nce',
#        'n.c.e, b.sc, ma, m.sc, b.tech, b.ed, m.ed, nce, m.a, hnd, mmed',
#        'mpa, ma, ond, nce', 'bsc, ma, ond, nce, mpa, mma, m a, hnd',
#        'ma, ond, nce, bachelor, mpa, m a',
#        'b.sc, ma, ond, mpa, nce, mea, hnd', 'bachelors, ma, nce',
#        'mpa, m!a, ma, nce', 'ma, ond, nce, mpa, mia, m a, mea',
#        'ond, ma, nce', 'ssce, bsc, hnd, ma', 'm a, ma, nce',
#        'ma, ond, mpa, mma, nce', 'mpa, mga, ma, nce',
#        'm a, ma, ond, bachelor, mpa, nce', 'mpa, ma, nce, ond', 'mpa',
#        'm a, ma, ond, bachelor, mba, mpa, mma, nce',
#        'm a, ma, ond, mpa, nce', 'ma, bachelor, ond, mpa, nce',
#        'b.sc, m a, ma, ond, n cre, mpa, nce',
#        'b.sc, m a, ma, ond, nce, hnd', 'm a, ma, mba, mpa, mma, nce, m.a',
#        'nce, m a, ma, ond', 'mpa, hnd, ma, nce',
#        'ma, nce, ond, bachelor, mpa, mia, m a, bachelors, mea, m/a',
#        'mpa, ma, nce', 'm a, ma, ond, bachelor, mpa, nce, mea', 'mga, ma',
#        'b.sc, pgd, ond, mpa, nce, hnd', 'mpa, b.sc, ma, nce', 'ma',
#        'mpa, nce, ma, bachelor', 'n cre, m!a, ma, nce',
#        'mpa, s succe, ma, nce', 'ma, bachelor, nce, mpa, m a',
#        'ma, bachelor, mpa, msc, nce', 'ma, nce, bachelor, mpa, m a, mea',
#        'b.sc, ma, ond, mpa, nce', 'nce, ma, bachelor',
#        'm a, ma, n cre, mpa, nce, mea', 'nce',
#        'ma, bachelor, nce, mma, m a',
#        'b.sc, ma, nce, mpa, nycre, m a, hnd', 'mma, ma, nce, bachelor',
#        'mpa, mmed, nce', 'b.sc, niche, ma, mba, mpa, nce',
#        'b.sc, niche, ma, ond, mpa, nce, hnd', 'mma',
#        'ma, bachelor, mpa, mma, nce', 'ond, mba, ma, nce',
#        'm a, ma, ond, bachelor, mpa, mma, nce, mea',
#        'm sc, ma, s succe, mpa, nce', 'm a, ma, bachelor, mpa, mma, nce',
#        'm a, mbed, ma, ond, mba, mpa, mma, nce', 'mpa, ond, ma, nce',
#        'm a, ma, ond, mba, mpa, mma, nce, m.a', 'ma, nce, bachelor',
#        'b.sc, ma, mpa, nce, hnd', 'bsc, ma, ond, mpa, nce, hnd',
#        'mpa, ma', 'nce, bachelor, ma, ond', 'mpa, ma, ond',
#        'n cle, ssce, m a, ma, ond, mpa, nce', 'bachelors, m a, ma, nce',
#        'bsc, ma, ond, mpa, hnd', 'm a, ma, ond, bachelor, mba, mpa, nce',
#        'ma, nce, bachelor, mpa, mma, m a, hnd',
#        'n cle, m a, ma, mpa, nce', 'mpa, ma, bachelor',
#        'mpa, bsc, ma, nce', 'b.sc, m a, ma, ond, mpa, nce, mea, hnd',
#        'ma, bachelor, mpa, nce, hnd', 'ma, ond, bachelor, mpa, nce',
#        'b.sc, ma, ond, nce, hnd', 'mpa, nce, ma, m a',
#        'b.sc, ma, nce, mpa, m a, hnd', 'mpa, msa, ma, nce',
#        'ma, ond, bachelor, mba, mpa, mma, nce',
#        'b.sc, ma, ond, mpa, mia, nce, hnd', 'ma, nce, ond, mpa, m a, phd'],
#       dtype=object)

# %%
len(df['Degree Type'].unique())
# Out:
# 90

# %%
len(df.Title.unique())
# Out:
# 105

# %%
df.shape
# Out:
# (704, 5)

# %%
df['Degree Type'].value_counts()
# Out:
#                                          44
# m a, ma, nce                             35
# mpa, nce, ma, ond                        33
# mpa, m!a, ma, nce                        29
# ma, ond, nce, mpa, m a                   25
#                                          ..
# b.sc, ma, ond, nce, hnd                   1
# mpa, bsc, ma, nce                         1
# m sc, ma, s succe, mpa, nce               1
# ma, ond, bachelor, mba, mpa, mma, nce     1
# nce, bachelor, ma, ond                    1
# Name: Degree Type, Length: 90, dtype: int64

# %%
len(df['Degree Type'].unique())
# Out:
# 90

# %%
df.dtypes
# Out:
# Title              object
# Job Description    object
# Company Name       object
# Location           object
# Degree Type        object
# dtype: object

# %%
df.head()
# Out:
#                              Title  \
# 0               Front Desk Officer
# 1  Customer Service Representative
# 2                       Accountant
# 3  Customer Service Representative
# 4                        Assistant
#
#                                      Job Description  \
# 0  * oversee all secretarial duties at entrance d...
# 1  the ideal candidate loves talking to people an...
# 2  •preparation of petty cash.• posting of petty ...
# 3  summaryour client, (a reputable retail gas sto...
# 4  i need an assistant who is very proficient in ...
#
#                    Company Name Location  \
# 0            TD Global Resource    Lagos
# 1  IQ SYSTEMS SOLUTIONS LIMITED    Lagos
# 2      Health insurance company    Lagos
# 3                    WorQulture    Lagos
# 4      The Image Makers Company    Lagos
#
#                                     Degree Type
# 0                        bsc, ma, nce, m a, hnd
# 1                             nce, msa, ma, ond
# 2
# 3  ma, ond, bachelor, n cre, mpa, mma, nce, mea
# 4

# %%
dff.head()
# Out:
#                              Title  \
# 0               Front Desk Officer
# 1  Customer Service Representative
# 2                       Accountant
# 3                        Assistant
# 4                HR Representative
#
#                                               Skills
# 0  manning the switchboard, receiving, endorsing ...
# 1  General Managerial/Administration, CRM systems...
# 2  financial reporting principles, MS Office, ACA...
# 3  Outlook, Excel, Word, PowerPoint, Google Sprea...
# 4  Human Resources or related discipline, Labour ...

# %%
dff.Title.unique()
# Out:
# array(['Front Desk Officer', 'Customer Service Representative',
#        'Accountant', 'Assistant', 'HR Representative', 'Oracle',
#        'Legal/Governance/HR Executive', 'Human Resources Supervisor',
#        'Customer Service Officer', 'Program Associate',
#        'Graduate Trainee', 'Store Officer', 'Head Of Human Resources',
#        'Office Clerk', 'Accountant/Auditor', 'Remote Job',
#        'Project Coordinator', 'Risk Advisor', 'Subject Teachers',
#        'Trainee Industrial', 'OPERATIONS/ADMIN MANAGER',
#        'Secretary/Personal Assistant', 'Receptionist & Cashier',
#        'REVENUE MANAGER', 'Nutrition Specialist',
#        'Public Health Administrative Management Assistant at the U.S. Embassy',
#        'Software Testers/IT Help Desk', 'DIGITAL MARKETING EXECUTIVE',
#        'Executive Assistant', 'Admin Lead',
#        'Communications Officer (NOB), FT at the United Nations International Children�s Emergency Fund (UNICEF)',
#        'Procurement/Purchasing Officer', 'Cashier',
#        'Communication for Development Specialist � NERICC at the United Nations International Children�s Emergency Fund (UNICEF)',
#        'Food & Beverage Manager',
#        'Medical Laboratory Scientist (Entry-level) at Arkounting Business Concepts Limited',
#        'Agricultural Process Leader', 'Office Secretary',
#        'Human Resources Generalist at Scib Nigeria & Co. Limited',
#        'Human Resources Intern', 'Laboratory Personnel',
#        'Graduate Energy Accounting Officer', 'Finance Manager',
#        'Head Of Business Operations', 'Waste Management Operator',
#        'Water Treatment Plant Operator',
#        'Associate Product Marketing Manager, Platforms and Ecosystems',
#        'Account Manager', 'Software Engineer',
#        'Nigeria Administration & Procurement Manager',
#        'Customer Care Officer', 'Junior Accountant',
#        'Inspection Personnel', 'Partnerships & Sustainability Associate',
#        'Teaching Staff', 'Inventory Officer',
#        'Quality Assurance Analyst - Call Centre', 'Inventory Accountant',
#        'Accounting Officer Location', 'Chief Operating Officer',
#        'External Facilitator', 'Procurement Officer', 'Receptionist',
#        'Customer Service Lead & Marketing  Rep', 'Marketing Coordinator',
#        'VISA OFFICER', 'Field Support Technician', 'HR Officer',
#        'Security Investigator', 'Head of Programmes and Influencing',
#        'Customer Service Executive', 'Travel Coordinator',
#        'School Human Resources Administrator', 'Hotel Manager',
#        'Station Manager', 'Administrative Logistics officer',
#        'Marketing Manager', 'Head Of Business',
#        'Partner Operations Intern', 'Territory Sales Manager',
#        'Sales Officer', 'Investor Relation Manager',
#        'Administrative assistant', 'Social Media Coordinator',
#        'Digital Transformation Manager', 'Customer Support Officer',
#        'Customer Service Manager', 'Office clerk', 'General Manager',
#        'Shipping and clearing Officer', 'Administrative Assistant',
#        'Graduate HR Intern', 'Senior Lead- Human Resources',
#        'English and Math Tutor', 'Administration Manager',
#        'Assistant Accountant', 'Junior Process Engineer',
#        'Junior Audit Officer', 'Administrative Officer',
#        'Graduate Management Trainee', 'Nutritionist',
#        'Head Treasury Marketing', 'Utilities Maintenance Controller',
#        'Medical Science Liaison Officer'], dtype=object)

# %%
df.replace({'Title':{ 'Customer Service Officer at Pruvia Integrated Limited': 'Customer Service Officer'}}, inplace=True)

# %%
df.replace({'Title':{ 'Communications Officer (NOB), FT at the United Nations International Children’s Emergency Fund (UNICEF)': 'Communications Officer',
                     'English and Math Instructor': 'English and Math Tutor',
                     "'Administrative Logistics officer" : 'Administrative Logistics officer',
                     'Accountant Auditor' : 'Accountant/Auditor',
                      'Graduate trainee' : 'Graduate Trainee',
                     'Subject Teachers ' : 'Subject Teachers',
                     'Communication for Development Specialist – NERICC at the United Nations International Children’s Emergency Fund (UNICEF)' : 'Communication for Development Specialist',
                     'Quality Assurance Analyst - Call Centre ' : 'Quality Assurance Analyst - Call Centre',
                     
                     
                    
                    
                    }}, inplace=True)

# %%
dff.replace({'Title':{ 'Communications Officer (NOB), FT at the United Nations International Children�s Emergency Fund (UNICEF)': 'Communications Officer',
                      
                     'Communication for Development Specialist � NERICC at the United Nations International Children�s Emergency Fund (UNICEF)': 'Communication for Development Specialist'
                     
                     
                     
                     
                     }}, inplace=True)

# %%
df_merge = df.merge(dff, how='left', on='Title')

# %%
df_merge[df_merge['Title']=='Communications Officer']
# Out:
#                       Title  \
# 56   Communications Officer
# 93   Communications Officer
# 294  Communications Officer
# 368  Communications Officer
#
#                                        Job Description  \
# 56   never miss a job update again. company: locati...
# 93   never miss a job update again. company: locati...
# 294  never miss a job update again. company: locati...
# 368  never miss a job update again. company: locati...
#
#                                           Company Name Location  \
# 56   United Nations International Children’s Emerge...    Abuja
# 93   United Nations International Children’s Emerge...    Abuja
# 294  United Nations International Children’s Emerge...    Abuja
# 368  United Nations International Children’s Emerge...    Abuja
#
#                           Degree Type  \
# 56   m a, ma, mba, mpa, mma, nce, m.a
# 93   m a, ma, mba, mpa, mma, nce, m.a
# 294  m a, ma, mba, mpa, mma, nce, m.a
# 368  m a, ma, mba, mpa, mma, nce, m.a
#
#                                                 Skills
# 56   Computer Aid Dispatch (CAD), Dispatch systems,...
# 93   Computer Aid Dispatch (CAD), Dispatch systems,...
# 294  Computer Aid Dispatch (CAD), Dispatch systems,...
# 368  Computer Aid Dispatch (CAD), Dispatch systems,...

# %%
df_merge[df_merge.Skills.isna()]['Title'].unique()
# Out:
# array([], dtype=object)

# %%
df_merge.head(10)
# Out:
#                              Title  \
# 0               Front Desk Officer
# 1  Customer Service Representative
# 2                       Accountant
# 3  Customer Service Representative
# 4                        Assistant
# 5                HR Representative
# 6                           Oracle
# 7    Legal/Governance/HR Executive
# 8    Legal/Governance/HR Executive
# 9       Human Resources Supervisor
#
#                                      Job Description  \
# 0  * oversee all secretarial duties at entrance d...
# 1  the ideal candidate loves talking to people an...
# 2  •preparation of petty cash.• posting of petty ...
# 3  summaryour client, (a reputable retail gas sto...
# 4  i need an assistant who is very proficient in ...
# 5  never miss a job update again. company: locati...
# 6  never miss a job update again. company: locati...
# 7  job briefwe are a corporate services firm that...
# 8  job briefwe are a corporate services firm that...
# 9  vacancy: hr supervisorindustry: professional s...
#
#                    Company Name Location  \
# 0            TD Global Resource    Lagos
# 1  IQ SYSTEMS SOLUTIONS LIMITED    Lagos
# 2      Health insurance company    Lagos
# 3                    WorQulture    Lagos
# 4      The Image Makers Company    Lagos
# 5    Dangote Industries Limited     Kogi
# 6                Oracle Limited    Lagos
# 7    KNN Corporate Services Ltd    Lagos
# 8    KNN Corporate Services Ltd    Lagos
# 9              Fosad Consulting    Lagos
#
#                                     Degree Type  \
# 0                        bsc, ma, nce, m a, hnd
# 1                             nce, msa, ma, ond
# 2
# 3  ma, ond, bachelor, n cre, mpa, mma, nce, mea
# 4
# 5                             mpa, nce, ma, ond
# 6                             mpa, mea, ma, nce
# 7                        ma, ond, nce, mpa, m a
# 8                        ma, ond, nce, mpa, m a
# 9                       bachelors, mpa, ma, nce
#
#                                               Skills
# 0  manning the switchboard, receiving, endorsing ...
# 1  General Managerial/Administration, CRM systems...
# 2  financial reporting principles, MS Office, ACA...
# 3  General Managerial/Administration, CRM systems...
# 4  Outlook, Excel, Word, PowerPoint, Google Sprea...
# 5  Human Resources or related discipline, Labour ...
# 6  Cloud Service experience, selling technology-r...
# 7  Telecom Technologies, Internet of Things, Smar...
# 8  Telecom Technologies, Internet of Things, Smar...
# 9  CHR, SHRM, CIPD, Microsoft Office applications...

# %%
df_merge['Degree Type'].isnull().sum()
# Out:
# 0

# %%
df_merge.sample(50)
# Out:
#                                                  Title  \
# 175                                       Office Clerk
# 382                            Head Of Human Resources
# 590                                 Accountant/Auditor
# 16                                        Office Clerk
# 679                                    REVENUE MANAGER
# 581                      Legal/Governance/HR Executive
# 207                      Legal/Governance/HR Executive
# 628                                    Finance Manager
# 82                             Head Of Human Resources
# 629                        Head Of Business Operations
# 353                                 Trainee Industrial
# 451                                       Risk Advisor
# 421                            Territory Sales Manager
# 488                         Human Resources Supervisor
# 648       Nigeria Administration & Procurement Manager
# 560                                             Oracle
# 582                         Human Resources Supervisor
# 596                                          Assistant
# 531                                   Graduate Trainee
# 676                           OPERATIONS/ADMIN MANAGER
# 2                                           Accountant
# 281                            Head Of Human Resources
# 107                               Laboratory Personnel
# 160  Associate Product Marketing Manager, Platforms...
# 372                    Customer Service Representative
# 336                    Customer Service Representative
# 564                                   Graduate Trainee
# 611  Medical Laboratory Scientist (Entry-level) at ...
# 104                                    REVENUE MANAGER
# 703                 Graduate Energy Accounting Officer
# 462                        Agricultural Process Leader
# 177                        Accounting Officer Location
# 607                                   Subject Teachers
# 464                                 Trainee Industrial
# 410                     Digital Transformation Manager
# 612                        Agricultural Process Leader
# 486                                  HR Representative
# 341                           Customer Service Officer
# 203                                          Assistant
# 485                                   Graduate Trainee
# 220                              Customer Care Officer
# 37                                          Accountant
# 199                                Project Coordinator
# 344                                   Graduate Trainee
# 265                          Waste Management Operator
# 573                            Territory Sales Manager
# 691                                         Accountant
# 179                               External Facilitator
# 641                                          Assistant
# 374                                             Oracle
#
#                                        Job Description  \
# 175  never miss a job update again. company: locati...
# 382  a multinational pharmaceutical/nutraceutical m...
# 590  duties/responsibilities:* examines assigned fi...
# 16   never miss a job update again. company: locati...
# 679  ibis hotel"some say you can't put a price on c...
# 581  job briefwe are a corporate services firm that...
# 207  job briefwe are a corporate services firm that...
# 628  reporting to the cfo, the finance manager role...
# 82   a multinational pharmaceutical/nutraceutical m...
# 629  gwcu canada ltd, a lending organization is int...
# 353  área de atuaçãoindustriallocalizaçãodelta-mgat...
# 451  never miss a job update again. company: locati...
# 421  never miss a job update again. company: locati...
# 488  vacancy: hr supervisorindustry: professional s...
# 648  job title: administration & procurement manage...
# 560  never miss a job update again. company: locati...
# 582  vacancy: hr supervisorindustry: professional s...
# 596  i need an assistant who is very proficient in ...
# 531  candidate must be domiciled in/around lagos.ca...
# 676  the ideal candidate will be responsible for ov...
# 2    •preparation of petty cash.• posting of petty ...
# 281  a multinational pharmaceutical/nutraceutical m...
# 107  never miss a job update again. company: locati...
# 160  minimum qualifications:bachelor's degree or eq...
# 372  summaryour client, (a reputable retail gas sto...
# 336  summaryour client, (a reputable retail gas sto...
# 564  candidate must be domiciled in/around lagos.ca...
# 611  never miss a job update again. company: locati...
# 104  ibis hotel"some say you can't put a price on c...
# 703  never miss a job update again. company: locati...
# 462  área de atuaçãodiversoslocalizaçãodelta-mgatri...
# 177  never miss a job update again. company: locati...
# 607  a prestigious international schools group in i...
# 464  área de atuaçãoindustriallocalizaçãodelta-mgat...
# 410  never miss a job update again. company: locati...
# 612  área de atuaçãodiversoslocalizaçãodelta-mgatri...
# 486  never miss a job update again. company: locati...
# 341  never miss a job update again. company: locati...
# 203  i need an assistant who is very proficient in ...
# 485  ensure high levels of customer satisfaction th...
# 220  1.    provide exceptional customer service exp...
# 37   company descriptionour client is renowned logi...
# 199  never miss a job update again. company: locati...
# 344  candidate must be domiciled in/around lagos.ca...
# 265  never miss a job update again. company: locati...
# 573  never miss a job update again. company: locati...
# 691  •preparation of petty cash.• posting of petty ...
# 179  never miss a job update again. company: locati...
# 641  urgent vacancy!a reputable school in nkpor ana...
# 374  never miss a job update again. company: locati...
#
#                                           Company Name       Location  \
# 175                          Pruvia Integrated Limited          Lagos
# 382             Pharmaceutical & Nutraceutical Company          Lagos
# 590                                     Chiji14xchange          Lagos
# 16                           Pruvia Integrated Limited          Lagos
# 679                                               IBIS          Lagos
# 581                         KNN Corporate Services Ltd          Lagos
# 207                         KNN Corporate Services Ltd          Lagos
# 628                              Africa Prudential Plc          Lagos
# 82              Pharmaceutical & Nutraceutical Company          Lagos
# 629                                    GWCU CANADA LTD          Abuja
# 353                                     Expresso Vagas          Delta
# 451                                   Deloitte Nigeria          Lagos
# 421                              Blume Nigeria Limited          Lagos
# 488                                   Fosad Consulting          Lagos
# 648                       ENGIE Energy Access (Africa)          Lagos
# 560                                     Oracle Limited          Lagos
# 582                                   Fosad Consulting          Lagos
# 596                           The Image Makers Company          Lagos
# 531                           EK Resources Nigeria Ltd          Lagos
# 676                 A client of The CVM Career Company          Lagos
# 2                             Health insurance company          Lagos
# 281             Pharmaceutical & Nutraceutical Company          Lagos
# 107                         Dangote Petroleum Refinery          Lagos
# 160                                             Google          Lagos
# 372                                         WorQulture          Lagos
# 336                                         WorQulture          Lagos
# 564                           EK Resources Nigeria Ltd          Lagos
# 611               Arkounting Business Concepts Limited          Lagos
# 104                                               IBIS          Lagos
# 703                                     Ikeja Electric          Lagos
# 462                                     Expresso Vagas          Delta
# 177                                     Royal Hospital          Enugu
# 607  A prestigeous group of Schools in Lagos and En...          Lagos
# 464                                     Expresso Vagas          Delta
# 410                            Alert Microfinance Bank          Lagos
# 612                                     Expresso Vagas          Delta
# 486                         Dangote Industries Limited           Kogi
# 341                          Pruvia Integrated Limited          Lagos
# 203                           The Image Makers Company          Lagos
# 485                                                LDG          Lagos
# 220                       Bodyline fitness and Gym Ltd          Lagos
# 37                       Myrtle Management Consultants  Port Harcourt
# 199                                              Oxfam         Bauchi
# 344                           EK Resources Nigeria Ltd          Lagos
# 265             Padua Petroleum Nigeria Limited (PPNL)          Lagos
# 573                              Blume Nigeria Limited          Lagos
# 691                           Health insurance company          Lagos
# 179                                  Médecins du Monde          Borno
# 641                                       Hiring Alert        Onitsha
# 374                                     Oracle Limited          Lagos
#
#                                            Degree Type  \
# 175                  b.sc, ma, ond, mpa, nce, mea, hnd
# 382                   ma, ond, nce, bachelor, mpa, m a
# 590                                 bachelors, ma, nce
# 16                   b.sc, ma, ond, mpa, nce, mea, hnd
# 679                                       m a, ma, nce
# 581                             ma, ond, nce, mpa, m a
# 207                             ma, ond, nce, mpa, m a
# 628                              mpa, s succe, ma, nce
# 82                    ma, ond, nce, bachelor, mpa, m a
# 629                                       m a, ma, nce
# 353                                  mpa, mga, ma, nce
# 451                                  mpa, nce, ma, ond
# 421                                       mpa, ma, nce
# 488                            bachelors, mpa, ma, nce
# 648                      m a, ma, n cre, mpa, nce, mea
# 560                                  mpa, mea, ma, nce
# 582                            bachelors, mpa, ma, nce
# 596
# 531                                  mpa, ma, ond, nce
# 676                   m a, ma, ond, bachelor, mpa, nce
# 2
# 281                   ma, ond, nce, bachelor, mpa, m a
# 107                             mpa, nce, ma, bachelor
# 160                   ma, nce, bachelor, mpa, m a, mea
# 372       ma, ond, bachelor, n cre, mpa, mma, nce, mea
# 336       ma, ond, bachelor, n cre, mpa, mma, nce, mea
# 564                                  mpa, ma, ond, nce
# 611              m a, ma, ond, bachelor, mpa, nce, mea
# 104                                       m a, ma, nce
# 703                                       mpa, ma, nce
# 462                                            mga, ma
# 177                                     mpa, mmed, nce
# 607                                       m a, ma, nce
# 464                                  mpa, mga, ma, nce
# 410                                       mpa, ma, nce
# 612                                            mga, ma
# 486                                  mpa, nce, ma, ond
# 341                            ssce, ma, ond, mpa, nce
# 203
# 485                                       ond, ma, nce
# 220                                       m a, ma, nce
# 37                              ma, ond, mpa, mma, nce
# 199                   ma, ond, nce, mpa, mia, m a, mea
# 344                                  mpa, ma, ond, nce
# 265                        ma, bachelor, nce, mpa, m a
# 573                                       mpa, ma, nce
# 691
# 179                                  mpa, nce, ma, ond
# 641  n.c.e, b.sc, ma, m.sc, b.tech, b.ed, m.ed, nce...
# 374                                  mpa, mea, ma, nce
#
#                                                 Skills
# 175  Computer skills, Microsoft Word, Excel, Powerp...
# 382  employment-related laws, regulations, Microsof...
# 590  ICAN, ANAN ACCA, CIA, MS Office, ERP , CISA, C...
# 16   Computer skills, Microsoft Word, Excel, Powerp...
# 679   Microsoft Excel, Powerpoint, Sales report, Ce...
# 581  Telecom Technologies, Internet of Things, Smar...
# 207  Telecom Technologies, Internet of Things, Smar...
# 628  forecasting, Strategic planning, Business deve...
# 82   employment-related laws, regulations, Microsof...
# 629  Interpersonal skills, risk assessment and anal...
# 353  MS word, Powerpoint, Excel, Wordpress, use bas...
# 451  Governance and Accountability, ICAN, ACCA,CIA ...
# 421  Microsoft office programs, Consumer sales tech...
# 488  CHR, SHRM, CIPD, Microsoft Office applications...
# 648  Negotiation skills, project management skills,...
# 560  Cloud Service experience, selling technology-r...
# 582  CHR, SHRM, CIPD, Microsoft Office applications...
# 596  Outlook, Excel, Word, PowerPoint, Google Sprea...
# 531  leadership, self-motivated, management skills,...
# 676  project management, delegation, flexibility, r...
# 2    financial reporting principles, MS Office, ACA...
# 281  employment-related laws, regulations, Microsof...
# 107  Pipetting, Sterilisation, Time management, Dat...
# 160  Marketing skills, UX design, brand management,...
# 372  General Managerial/Administration, CRM systems...
# 336  General Managerial/Administration, CRM systems...
# 564  leadership, self-motivated, management skills,...
# 611  Diagnostic tests, Effective use of lab equipme...
# 104   Microsoft Excel, Powerpoint, Sales report, Ce...
# 703  Analytical Skill, Health and Safety skills, Bu...
# 462  Mechanical and repairing, Problem solving, Tec...
# 177  Financial statement analysis, debt management,...
# 607  Nigerian and British curriculum, Microsoft Wor...
# 464  MS word, Powerpoint, Excel, Wordpress, use bas...
# 410  Information Systems,Computer Science, project ...
# 612  Mechanical and repairing, Problem solving, Tec...
# 486  Human Resources or related discipline, Labour ...
# 341  Computer literacy, sales experience, customer ...
# 203  Outlook, Excel, Word, PowerPoint, Google Sprea...
# 485  leadership, self-motivated, management skills,...
# 220  microsoft office, active listening skills, typ...
# 37   financial reporting principles, MS Office, ACA...
# 199  PMP / PRINCE2, Microsoft Project , Microsoft P...
# 344  leadership, self-motivated, management skills,...
# 265  Attention to details, team work, waste managem...
# 573  Microsoft office programs, Consumer sales tech...
# 691  financial reporting principles, MS Office, ACA...
# 179  Innovation and technology, negotiation skills,...
# 641  Outlook, Excel, Word, PowerPoint, Google Sprea...
# 374  Cloud Service experience, selling technology-r...

# %%
pd.set_option('display.max_colwidth', None)

# %%
df_merge.to_csv('jobdata_updated.csv')

# %%
df_merge['Degree Type'].unique()
# Out:
# array(['bsc, ma, nce, m a, hnd', 'nce, msa, ma, ond', '',
#        'ma, ond, bachelor, n cre, mpa, mma, nce, mea',
#        'mpa, nce, ma, ond', 'mpa, mea, ma, nce', 'ma, ond, nce, mpa, m a',
#        'bachelors, mpa, ma, nce', 'ssce, ma, ond, mpa, nce',
#        'b.sc, m a, ma, nce',
#        'n.c.e, b.sc, ma, m.sc, b.tech, b.ed, m.ed, nce, m.a, hnd, mmed',
#        'mpa, ma, ond, nce', 'bsc, ma, ond, nce, mpa, mma, m a, hnd',
#        'ma, ond, nce, bachelor, mpa, m a',
#        'b.sc, ma, ond, mpa, nce, mea, hnd', 'bachelors, ma, nce',
#        'mpa, m!a, ma, nce', 'ma, ond, nce, mpa, mia, m a, mea',
#        'ond, ma, nce', 'ssce, bsc, hnd, ma', 'm a, ma, nce',
#        'ma, ond, mpa, mma, nce', 'mpa, mga, ma, nce',
#        'm a, ma, ond, bachelor, mpa, nce', 'mpa, ma, nce, ond', 'mpa',
#        'm a, ma, ond, bachelor, mba, mpa, mma, nce',
#        'm a, ma, ond, mpa, nce', 'ma, bachelor, ond, mpa, nce',
#        'b.sc, m a, ma, ond, n cre, mpa, nce',
#        'b.sc, m a, ma, ond, nce, hnd', 'm a, ma, mba, mpa, mma, nce, m.a',
#        'nce, m a, ma, ond', 'mpa, hnd, ma, nce',
#        'ma, nce, ond, bachelor, mpa, mia, m a, bachelors, mea, m/a',
#        'mpa, ma, nce', 'm a, ma, ond, bachelor, mpa, nce, mea', 'mga, ma',
#        'b.sc, pgd, ond, mpa, nce, hnd', 'mpa, b.sc, ma, nce', 'ma',
#        'mpa, nce, ma, bachelor', 'n cre, m!a, ma, nce',
#        'mpa, s succe, ma, nce', 'ma, bachelor, nce, mpa, m a',
#        'ma, bachelor, mpa, msc, nce', 'ma, nce, bachelor, mpa, m a, mea',
#        'b.sc, ma, ond, mpa, nce', 'nce, ma, bachelor',
#        'm a, ma, n cre, mpa, nce, mea', 'nce',
#        'ma, bachelor, nce, mma, m a',
#        'b.sc, ma, nce, mpa, nycre, m a, hnd', 'mma, ma, nce, bachelor',
#        'mpa, mmed, nce', 'b.sc, niche, ma, mba, mpa, nce',
#        'b.sc, niche, ma, ond, mpa, nce, hnd', 'mma',
#        'ma, bachelor, mpa, mma, nce', 'ond, mba, ma, nce',
#        'm a, ma, ond, bachelor, mpa, mma, nce, mea',
#        'm sc, ma, s succe, mpa, nce', 'm a, ma, bachelor, mpa, mma, nce',
#        'm a, mbed, ma, ond, mba, mpa, mma, nce', 'mpa, ond, ma, nce',
#        'm a, ma, ond, mba, mpa, mma, nce, m.a', 'ma, nce, bachelor',
#        'b.sc, ma, mpa, nce, hnd', 'bsc, ma, ond, mpa, nce, hnd',
#        'mpa, ma', 'nce, bachelor, ma, ond', 'mpa, ma, ond',
#        'n cle, ssce, m a, ma, ond, mpa, nce', 'bachelors, m a, ma, nce',
#        'bsc, ma, ond, mpa, hnd', 'm a, ma, ond, bachelor, mba, mpa, nce',
#        'ma, nce, bachelor, mpa, mma, m a, hnd',
#        'n cle, m a, ma, mpa, nce', 'mpa, ma, bachelor',
#        'mpa, bsc, ma, nce', 'b.sc, m a, ma, ond, mpa, nce, mea, hnd',
#        'ma, bachelor, mpa, nce, hnd', 'ma, ond, bachelor, mpa, nce',
#        'b.sc, ma, ond, nce, hnd', 'mpa, nce, ma, m a',
#        'b.sc, ma, nce, mpa, m a, hnd', 'mpa, msa, ma, nce',
#        'ma, ond, bachelor, mba, mpa, mma, nce',
#        'b.sc, ma, ond, mpa, mia, nce, hnd', 'ma, nce, ond, mpa, m a, phd'],
#       dtype=object)

# %%
newdf = df_merge.drop_duplicates(subset=None, keep='first', inplace=False)

# %%
len(df_merge.Title.unique())
# Out:
# 104

# %%
len(newdf.Title.unique())
# Out:
# 104

# %%
newdf.head()
# Out:
#                              Title  \
# 0               Front Desk Officer
# 1  Customer Service Representative
# 2                       Accountant
# 3  Customer Service Representative
# 4                        Assistant
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Job Description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             * oversee all secretarial duties at entrance desk* perform administrative responsibilities in an efficient manner* outstanding customer service skills* ability to prioritize multi tasks* excellent communication and organizational skills* fluent in it concepts*  hnd/bsc in any disciplineapply by sending cv to outsourcing4tdglobalresource@gmail.com
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       the ideal candidate loves talking to people and proactively solving issues. you will be responsible for converting customers into passionate evangelists  responsibilitiesensuring all havens under a sacr portfolio are in good working condition.ensure resolution of all issues (technical or otherwise) raised or may be raised by the school are resolved with 48 hours.ensure all students and their guardians are captured on iqss database.ensure newly enrolled students and their guardians are captured on iqss database within 48 hours of enrolment.identify key stakeholders within the organization.ensure all members of staff required to be captured in iqss database are captured.cross sell iqss mobile app to all parents and guardians of students in the school.cross sell iqss student management system to members of staffidentify opportunities within the school which can be leveraged on by iqss to improve its relationship with the client.identify threats from within and outside the school to the relationship between the school and iqss.spearhead engagements relating to relationship management between the school and iqss.spearhead the timely remittance by iqss of all requested reports by the schoolrender all reports to iqss within the stipulated timeframe. work with internal departments to meet customer's needsdata entry in various platformsqualificationsexcellent excellent verbal, written, and interpersonal skillsability to multi-task, organize, and prioritize workcomputer savvyif interested, email aadeyemi@iqs-solutions.comsalary : n51,000location:  ikoyi.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            •preparation of petty cash.• posting of petty cash vouchers.• imputing into gtb gaps application.• cheque writing where necessary.• issuing of invoices in conjunction with business development.• follow up on outstanding invoices in conjunction with business development.• settling of monthly capitation, fss in conjunction with the medical administrator and other non-medical invoices.•daily log in of all financial transactions into the system.
# 3  summaryour client, (a reputable retail gas store) is hiring for the role of a customer service and sale representative. as the customer service and sales representative you are expected to study the sales level of products, maintain, improve and monitor the daily business functions and also ensure that safety protocols are strictly adhered to. you will manage the flow of bookings and see to the delivery of gas products.the ideal candidate will have impeccable relational skills, good knowledge of operation, and can create win/win environments for all parties that he or she works with. you will be responsible for managing all enquiries, relating them to the relevant department, monitoring daily operations and ensuring every customer is satisfied.if you have what it takes to be hands-on, use your initiative and charm the socks off customers then you should apply.location: victoria islandwork hours: monday – saturday (9am-6pm), saturday (remotely)salary: 70,000 - 80,000availability to start: as soon as possibleresponsibilitiesensure that the highest safety standards are met and implementedimplement measures to ensure seamless and safe receipt, storage, handling and dispatch of products in the terminalgenerate weekly and monthly reports to management on the status of operations.ensure high levels of customers satisfaction through excellent serviceensure compliance with policies and proceduresmaintain outstanding station condition and merchandising standardsfollow up with client orders to ensure they are delivered to clients promptlydeliver the highest level of professional service to customersmanage the flow of bookings and see to the delivery of gas product from start to finishmaintain the cleanliness of the environmentrecord daily sales, receive and follow up on payment of all client ordersbuild processes that meet our business objective and ensure compliancemanaging point-of-sale processesactively involved in the receiving new productkeeping up to date with product informationmonitor financial data and recommend solutions that will improve profitabilityfollowing all companies policies and procedures requirementsrequirements• excellent verbal and written communications skills• strong interpersonal and analytical skills• detail-oriented• strong organizational skills• proficiency in excel• excellent time management, project organization, and follow-through skills.• demonstrated ability to increase customer satisfactionjob qualifications• bachelor's degree or equivalent experience• experience in customer success
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 i need an assistant who is very proficient in academic research and research writing. your responsibility will involve assisting me in carrying out my tasks. sending me previous academic writings you have done is an added advantage.
#
#                    Company Name Location  \
# 0            TD Global Resource    Lagos
# 1  IQ SYSTEMS SOLUTIONS LIMITED    Lagos
# 2      Health insurance company    Lagos
# 3                    WorQulture    Lagos
# 4      The Image Makers Company    Lagos
#
#                                     Degree Type  \
# 0                        bsc, ma, nce, m a, hnd
# 1                             nce, msa, ma, ond
# 2
# 3  ma, ond, bachelor, n cre, mpa, mma, nce, mea
# 4
#
#                                                                                                 Skills
# 0  manning the switchboard, receiving, endorsing letters, MS Office applications, accounting softwares
# 1                    General Managerial/Administration, CRM systems, Microsoft Excel, Word, PowerPoint
# 2                      financial reporting principles, MS Office, ACA, knowledge of O2C,AR, ERP system
# 3                    General Managerial/Administration, CRM systems, Microsoft Excel, Word, PowerPoint
# 4                                                Outlook, Excel, Word, PowerPoint, Google Spreadsheets

# %%
newdf['Degree Type'].unique()
# Out:
# array(['bsc, ma, nce, m a, hnd', 'nce, msa, ma, ond', '',
#        'ma, ond, bachelor, n cre, mpa, mma, nce, mea',
#        'mpa, nce, ma, ond', 'mpa, mea, ma, nce', 'ma, ond, nce, mpa, m a',
#        'bachelors, mpa, ma, nce', 'ssce, ma, ond, mpa, nce',
#        'b.sc, m a, ma, nce',
#        'n.c.e, b.sc, ma, m.sc, b.tech, b.ed, m.ed, nce, m.a, hnd, mmed',
#        'mpa, ma, ond, nce', 'bsc, ma, ond, nce, mpa, mma, m a, hnd',
#        'ma, ond, nce, bachelor, mpa, m a',
#        'b.sc, ma, ond, mpa, nce, mea, hnd', 'bachelors, ma, nce',
#        'mpa, m!a, ma, nce', 'ma, ond, nce, mpa, mia, m a, mea',
#        'ond, ma, nce', 'ssce, bsc, hnd, ma', 'm a, ma, nce',
#        'ma, ond, mpa, mma, nce', 'mpa, mga, ma, nce',
#        'm a, ma, ond, bachelor, mpa, nce', 'mpa, ma, nce, ond', 'mpa',
#        'm a, ma, ond, bachelor, mba, mpa, mma, nce',
#        'm a, ma, ond, mpa, nce', 'ma, bachelor, ond, mpa, nce',
#        'b.sc, m a, ma, ond, n cre, mpa, nce',
#        'b.sc, m a, ma, ond, nce, hnd', 'm a, ma, mba, mpa, mma, nce, m.a',
#        'nce, m a, ma, ond', 'mpa, hnd, ma, nce',
#        'ma, nce, ond, bachelor, mpa, mia, m a, bachelors, mea, m/a',
#        'mpa, ma, nce', 'm a, ma, ond, bachelor, mpa, nce, mea', 'mga, ma',
#        'b.sc, pgd, ond, mpa, nce, hnd', 'mpa, b.sc, ma, nce', 'ma',
#        'mpa, nce, ma, bachelor', 'n cre, m!a, ma, nce',
#        'mpa, s succe, ma, nce', 'ma, bachelor, nce, mpa, m a',
#        'ma, bachelor, mpa, msc, nce', 'ma, nce, bachelor, mpa, m a, mea',
#        'b.sc, ma, ond, mpa, nce', 'nce, ma, bachelor',
#        'm a, ma, n cre, mpa, nce, mea', 'nce',
#        'ma, bachelor, nce, mma, m a',
#        'b.sc, ma, nce, mpa, nycre, m a, hnd', 'mma, ma, nce, bachelor',
#        'mpa, mmed, nce', 'b.sc, niche, ma, mba, mpa, nce',
#        'b.sc, niche, ma, ond, mpa, nce, hnd', 'mma',
#        'ma, bachelor, mpa, mma, nce', 'ond, mba, ma, nce',
#        'm a, ma, ond, bachelor, mpa, mma, nce, mea',
#        'm sc, ma, s succe, mpa, nce', 'm a, ma, bachelor, mpa, mma, nce',
#        'm a, mbed, ma, ond, mba, mpa, mma, nce', 'mpa, ond, ma, nce',
#        'm a, ma, ond, mba, mpa, mma, nce, m.a', 'ma, nce, bachelor',
#        'b.sc, ma, mpa, nce, hnd', 'bsc, ma, ond, mpa, nce, hnd',
#        'mpa, ma', 'nce, bachelor, ma, ond', 'mpa, ma, ond',
#        'n cle, ssce, m a, ma, ond, mpa, nce', 'bachelors, m a, ma, nce',
#        'bsc, ma, ond, mpa, hnd', 'm a, ma, ond, bachelor, mba, mpa, nce',
#        'ma, nce, bachelor, mpa, mma, m a, hnd',
#        'n cle, m a, ma, mpa, nce', 'mpa, ma, bachelor',
#        'mpa, bsc, ma, nce', 'b.sc, m a, ma, ond, mpa, nce, mea, hnd',
#        'ma, bachelor, mpa, nce, hnd', 'ma, ond, bachelor, mpa, nce',
#        'b.sc, ma, ond, nce, hnd', 'mpa, nce, ma, m a',
#        'b.sc, ma, nce, mpa, m a, hnd', 'mpa, msa, ma, nce',
#        'ma, ond, bachelor, mba, mpa, mma, nce',
#        'b.sc, ma, ond, mpa, mia, nce, hnd', 'ma, nce, ond, mpa, m a, phd'],
#       dtype=object)

# %%
newdf["Degree Type"] = newdf["Degree Type"].apply(lambda x: x.replace("m a", ""))
# Out:
# <ipython-input-55-37edb9e7508d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf["Degree Type"] = newdf["Degree Type"].apply(lambda x: x.replace("m a", ""))

# %%
newdf.to_csv('jobb_data.csv')
